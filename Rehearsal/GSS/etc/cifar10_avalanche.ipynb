# %%
import torch
import pickle
import random
import torchvision
import numpy as np
import datetime as dt
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torchvision import transforms

from avalanche.training.supervised import GSS_greedy
from avalanche.logging import InteractiveLogger, TensorboardLogger
from avalanche.benchmarks.datasets import CIFAR100
from avalanche.benchmarks.generators import nc_benchmark
from avalanche.benchmarks.utils import AvalancheDataset, make_classification_dataset
from avalanche.training.plugins import EvaluationPlugin
from avalanche.evaluation.metrics import ExperienceAccuracy, ExperienceLoss, ExperienceForgetting, ExperienceTime, EpochAccuracy, StreamAccuracy

# %%
seed = 0
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
cudnn.enabled = False
cudnn.deterministic = True

# %%
train_set = CIFAR100('Dataset/CIFAR100', train=True, download=True)
test_set = CIFAR100('Dataset/CIFAR100', train=False, download=True)

transforms_group = dict(
        eval=(
            transforms.Compose(
                [
                    transforms.ToTensor(),
                ]
            ),
            None,
        ),
        train=(
            transforms.Compose(
                [
                    transforms.ToTensor(),
                ]
            ),
            None,
        ),
    )

train_set = CIFAR100('Dataset/CIFAR100', train=True,download=True,)
test_set = CIFAR100('Dataset/CIFAR100', train=False,download=True,)
train_set = make_classification_dataset(train_set, transform_groups=transforms_group, initial_transform_group="train",)
test_set = make_classification_dataset(test_set, transform_groups=transforms_group, initial_transform_group="eval",)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

num_class = 100
incremental = 10

scenario = nc_benchmark(train_dataset=train_set,
                        test_dataset=test_set,
                        n_experiences=incremental,
                        task_labels=False,
                        seed=seed,
                        shuffle=False
                        )

model = torchvision.models.resnet18(pretrained=False, num_classes=num_class)
model.to(device)

optimizer = optim.SGD(model.parameters(), lr=1e-2)
criterion = torch.nn.CrossEntropyLoss()
# Out:
# c:\Users\AI\anaconda3\envs\lab\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\AI\anaconda3\envs\lab\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
date = dt.datetime.now()
date = date.strftime("%Y_%m_%d_%H_%M_%S")

interactive_logger = InteractiveLogger()
tensor_logger = TensorboardLogger("logs_GSS-Greedy_cifar100_avalanche_" + date)
eval_plugin = EvaluationPlugin(
    EpochAccuracy(),
    ExperienceAccuracy(),
    StreamAccuracy(),
    loggers=[interactive_logger, tensor_logger])

# %% [markdown]
# ## GSS-Greedy

# %%
train_batch = 512
eval_batch = 512
epoch = 50

strategies = GSS_greedy(model, optimizer, criterion, mem_size=2000, mem_strength=10, input_size=[3, 32, 32], train_epochs=epoch, device=device, train_mb_size=train_batch, eval_mb_size=eval_batch, evaluator=eval_plugin)

# %%
print("Starting experiment...")
results = []

for experience in scenario.train_stream:
    print("Start training on experience ", experience.current_experience)
    strategies.train(experience)
    print("End training on experience ", experience.current_experience)
    print("Computing accuracy on the test set")
    results.append(strategies.eval(scenario.test_stream[:]))
# Out:
# Starting experiment...
# Start training on experience  0
# -- >> Start of training phase << --
# 100%|██████████| 10/10 [00:52<00:00,  5.23s/it]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.1452
# 100%|██████████| 10/10 [00:46<00:00,  4.60s/it]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3108
# 100%|██████████| 10/10 [00:46<00:00,  4.60s/it]
# Epoch 2 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.3982
# 100%|██████████| 10/10 [00:46<00:00,  4.63s/it]
# Epoch 3 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4314
# 100%|██████████| 10/10 [00:45<00:00,  4.57s/it]
# Epoch 4 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4086
# 100%|██████████| 10/10 [00:46<00:00,  4.64s/it]
# Epoch 5 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4664
# 100%|██████████| 10/10 [00:46<00:00,  4.63s/it]
# Epoch 6 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.4782
# 100%|██████████| 10/10 [00:46<00:00,  4.65s/it]
# Epoch 7 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5086
# 100%|██████████| 10/10 [00:46<00:00,  4.61s/it]
# Epoch 8 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5352
# 100%|██████████| 10/10 [00:46<00:00,  4.60s/it]
# Epoch 9 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5816
# 100%|██████████| 10/10 [00:46<00:00,  4.60s/it]
# Epoch 10 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.5796
# 100%|██████████| 10/10 [00:46<00:00,  4.60s/it]
# Epoch 11 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.
ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:44<00:00,  3.57s/it]
# Epoch 8 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:46<00:00,  3.59s/it]
# Epoch 9 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:29<00:00,  3.33s/it]
# Epoch 10 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.27s/it]
# Epoch 11 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:27<00:00,  3.29s/it]
# Epoch 12 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.27s/it]
# Epoch 13 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.28s/it]
# Epoch 14 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.27s/it]
# Epoch 15 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.28s/it]
# Epoch 16 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.27s/it]
# Epoch 17 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.28s/it]
# Epoch 18 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.28s/it]
# Epoch 19 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:25<00:00,  3.26s/it]
# Epoch 20 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.27s/it]
# Epoch 21 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:25<00:00,  3.26s/it]
# Epoch 22 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:27<00:00,  3.29s/it]
# Epoch 23 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.27s/it]
# Epoch 24 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.25s/it]
# Epoch 25 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 26 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 27 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:23<00:00,  3.23s/it]
# Epoch 28 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:23<00:00,  3.23s/it]
# Epoch 29 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:25<00:00,  3.26s/it]
# Epoch 30 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:23<00:00,  3.23s/it]
# Epoch 31 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.25s/it]
# Epoch 32 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 33 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:23<00:00,  3.24s/it]
# Epoch 34 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 35 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 36 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:23<00:00,  3.24s/it]
# Epoch 37 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.25s/it]
# Epoch 38 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.25s/it]
# Epoch 39 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 40 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:23<00:00,  3.24s/it]
# Epoch 41 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 42 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:23<00:00,  3.24s/it]
# Epoch 43 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 44 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:23<00:00,  3.22s/it]
# Epoch 45 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.27s/it]
# Epoch 46 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.28s/it]
# Epoch 47 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:27<00:00,  3.29s/it]
# Epoch 48 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# 100%|██████████| 63/63 [03:26<00:00,  3.28s/it]
# Epoch 49 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0058
# -- >> End of training phase << --
# End training on experience  1
# Computing accuracy on the test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 2/2 [00:00<00:00,  4.23it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.1000
# -- Starting eval on experience 1 (Task 0) from test stream --
# 100%|██████████| 2/2 [00:00<00:00,  4.23it/s]
# > Eval on experience 1 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 0) from test stream --
# 100%|██████████| 2/2 [00:00<00:00,  4.16it/s]
# > Eval on experience 2 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 0) from test stream --
# 100%|██████████| 2/2 [00:00<00:00,  4.13it/s]
# > Eval on experience 3 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 0) from test stream --
# 100%|██████████| 2/2 [00:00<00:00,  4.04it/s]
# > Eval on experience 4 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp004 = 0.0000
# -- Starting eval on experience 5 (Task 0) from test stream --
# 100%|██████████| 2/2 [00:00<00:00,  4.14it/s]
# > Eval on experience 5 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp005 = 0.0000
# -- Starting eval on experience 6 (Task 0) from test stream --
# 100%|██████████| 2/2 [00:00<00:00,  4.31it/s]
# > Eval on experience 6 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp006 = 0.0000
# -- Starting eval on experience 7 (Task 0) from test stream --
# 100%|██████████| 2/2 [00:00<00:00,  3.89it/s]
# > Eval on experience 7 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp007 = 0.0000
# -- Starting eval on experience 8 (Task 0) from test stream --
# 100%|██████████| 2/2 [00:00<00:00,  4.29it/s]
# > Eval on experience 8 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp008 = 0.0000
# -- Starting eval on experience 9 (Task 0) from test stream --
# 100%|██████████| 2/2 [00:00<00:00,  4.09it/s]
# > Eval on experience 9 (Task 0) from test stream ended.
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp009 = 0.0000
# -- >> End of eval phase << --
# 	Top1_Acc_Stream/eval_phase/test_stream/Task000 = 0.0100
# Start training on experience  2
# -- >> Start of training phase << --
# 100%|██████████| 63/63 [03:26<00:00,  3.28s/it]
# Epoch 0 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:27<00:00,  3.30s/it]
# Epoch 1 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:26<00:00,  3.28s/it]
# Epoch 2 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:27<00:00,  3.30s/it]
# Epoch 3 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:26<00:00,  3.28s/it]
# Epoch 4 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:26<00:00,  3.28s/it]
# Epoch 5 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:27<00:00,  3.29s/it]
# Epoch 6 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:25<00:00,  3.26s/it]
# Epoch 7 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:26<00:00,  3.28s/it]
# Epoch 8 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:25<00:00,  3.26s/it]
# Epoch 9 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:27<00:00,  3.29s/it]
# Epoch 10 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:25<00:00,  3.27s/it]
# Epoch 11 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:25<00:00,  3.27s/it]
# Epoch 12 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:25<00:00,  3.27s/it]
# Epoch 13 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 14 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 15 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:23<00:00,  3.24s/it]
# Epoch 16 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:24<00:00,  3.25s/it]
# Epoch 17 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 18 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 19 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 20 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:23<00:00,  3.23s/it]
# Epoch 21 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:24<00:00,  3.25s/it]
# Epoch 22 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 23 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:23<00:00,  3.23s/it]
# Epoch 24 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:23<00:00,  3.23s/it]
# Epoch 25 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 26 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
# 100%|██████████| 63/63 [03:24<00:00,  3.24s/it]
# Epoch 27 ended.
# 	Top1_Acc_Epoch/train_phase/train_stream/Task000 = 0.0046
#  14%|█▍        | 9/63 [00:42<04:21,  4.85s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\AI\Desktop\Continual-Learning\Rehearsal\GSS\cifar10_avalanche.ipynb 셀 8 in 6
#       <a href='vscode-notebook-cell:/c%3A/Users/AI/Desktop/Continual-Learning/Rehearsal/GSS/cifar10_avalanche.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> for experience in scenario.train_stream:
#       <a href='vscode-notebook-cell:/c%3A/Users/AI/Desktop/Continual-Learning/Rehearsal/GSS/cifar10_avalanche.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     print("Start training on experience ", experience.current_experience)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/AI/Desktop/Continual-Learning/Rehearsal/GSS/cifar10_avalanche.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>     strategies.train(experience)
#       <a href='vscode-notebook-cell:/c%3A/Users/AI/Desktop/Continual-Learning/Rehearsal/GSS/cifar10_avalanche.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>     print("End training on experience ", experience.current_experience)
#       <a href='vscode-notebook-cell:/c%3A/Users/AI/Desktop/Continual-Learning/Rehearsal/GSS/cifar10_avalanche.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a>     print("Computing accuracy on the test set")
#
# File c:\Users\AI\anaconda3\envs\lab\lib\site-packages\avalanche\training\templates\base_sgd.py:146, in BaseSGDTemplate.train(self, experiences, eval_streams, **kwargs)
#     139 def train(self,
#     140           experiences: Union[CLExperience,
#     141                              ExpSequence],
#     142           eval_streams: Optional[Sequence[Union[CLExperience,
#     143                                                 ExpSequence]]] = None,
#     144           **kwargs):
# --> 146     super().train(experiences, eval_streams, **kwargs)
#     147     return self.evaluator.get_last_metrics()
#
# File c:\Users\AI\anaconda3\envs\lab\lib\site-packages\avalanche\training\templates\base.py:116, in BaseTemplate.train(self, experiences, eval_streams, **kwargs)
#     114 for self.experience in experiences:
#     115     self._before_training_exp(**kwargs)
# --> 116     self._train_exp(self.experience, eval_streams, **kwargs)
#     117     self._after_training_exp(**kwargs)
#     118 self._after_training(**kwargs)
#
# File c:\Users\AI\anaconda3\envs\lab\lib\site-packages\avalanche\training\templates\base_sgd.py:264, in BaseSGDTemplate._train_exp(self, experience, eval_streams, **kwargs)
#     261     self._stop_training = False
#     262     break
# --> 264 self.training_epoch(**kwargs)
#     265 self._after_training_epoch(**kwargs)
#
# File c:\Users\AI\anaconda3\envs\lab\lib\site-packages\avalanche\training\templates\update_type\sgd_update.py:22, in SGDUpdate.training_epoch(self, **kwargs)
#      20 self._before_forward(**kwargs)
#      21 self.mb_output = self.forward()
# ---> 22 self._after_forward(**kwargs)
#      24 # Loss & Backward
#      25 self.loss += self.criterion()
#
# File c:\Users\AI\anaconda3\envs\lab\lib\site-packages\avalanche\training\templates\base_sgd.py:403, in BaseSGDTemplate._after_forward(self, **kwargs)
#     402 def _after_forward(self, **kwargs):
# --> 403     trigger_plugins(self, "after_forward", **kwargs)
#
# File c:\Users\AI\anaconda3\envs\lab\lib\site-packages\avalanche\training\utils.py:35, in trigger_plugins(strategy, event, **kwargs)
#      33 for p in strategy.plugins:
#      34     if hasattr(p, event):
# ---> 35         getattr(p, event)(strategy, **kwargs)
#
# File c:\Users\AI\anaconda3\envs\lab\lib\site-packages\avalanche\training\plugins\gss_greedy.py:200, in GSS_greedyPlugin.after_forward(self, strategy, num_workers, shuffle, **kwargs)
#     195 place_left = (
#     196     self.ext_mem_list_x.size(0) - self.ext_mem_list_current_index
#     197 )
#     198 if place_left <= 0:  # buffer full
# --> 200     batch_sim, mem_grads = self.get_batch_sim(
#     201         strategy,
#     202         grad_dims,
#     203         batch_x=strategy.mb_x,
#     204         batch_y=strategy.mb_y,
#     205     )
#     207     if batch_sim < 0:
#     208         buffer_score = self.buffer_score[
#     209             : self.ext_mem_list_current_index
#     210         ].cpu()
#
# File c:\Users\AI\anaconda3\envs\lab\lib\site-packages\avalanche\training\plugins\gss_greedy.py:80, in GSS_greedyPlugin.get_batch_sim(self, strategy, grad_dims, batch_x, batch_y)
#      71 def get_batch_sim(self, strategy, grad_dims, batch_x, batch_y):
#      72     """
#      73     Args:
#      74         buffer: memory buffer
#    (...)
#      78     Returns: score of current batch, gradient from memory subsets
#      79     """
# ---> 80     mem_grads = self.get_rand_mem_grads(strategy, grad_dims, len(batch_x))
#      81     strategy.model.zero_grad()
#      82     loss = strategy._criterion(strategy.model.forward(batch_x), batch_y)
#
# File c:\Users\AI\anaconda3\envs\lab\lib\site-packages\avalanche\training\plugins\gss_greedy.py:122, in GSS_greedyPlugin.get_rand_mem_grads(self, strategy, grad_dims, gss_batch_size)
#     119     strategy.model.zero_grad()
#     121     loss = strategy._criterion(strategy.model.forward(batch_x), batch_y)
# --> 122     loss.backward()
#     123     mem_grads[i].data.copy_(
#     124         self.get_grad_vector(strategy.model.parameters, grad_dims)
#     125     )
#     126 return mem_grads
#
# File c:\Users\AI\anaconda3\envs\lab\lib\site-packages\torch\_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File c:\Users\AI\anaconda3\envs\lab\lib\site-packages\torch\autograd\__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
